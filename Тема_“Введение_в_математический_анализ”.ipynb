# %% [markdown]
# <a href="https://colab.research.google.com/github/LukmanovaLiliya/-/blob/main/%D0%A2%D0%B5%D0%BC%D0%B0_%E2%80%9C%D0%92%D0%B2%D0%B5%D0%B4%D0%B5%D0%BD%D0%B8%D0%B5_%D0%B2_%D0%BC%D0%B0%D1%82%D0%B5%D0%BC%D0%B0%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B8%D0%B9_%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7%E2%80%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Задание 1**
# *Как соотносятся понятия “множество” и “последовательность”? (в ответе использовать слова типа: часть, целое, общее, частное, родитель, дочерний субъект и т. д.)*

# %% [markdown]
# Последовательность - это родитель, а множество  - дочерний субъект, ибо элементы в последовательности могут сопадать, например {1,1,1},  а в множестве все элементы уникальны.

# %% [markdown]
# **Задание №2** -

# %% [markdown]
# ![Снимок.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# 1. Все элементы у в пределах от 0 до 1 имеют функцию сигнум =1.
# ЛОЖЬ, так как 0 входит в период.
#
# Если делать отрицание, то тогда утверждение станет ИСТИНА

# %% [markdown]
# с остальными утверждениями возникли сложности.....

# %% [markdown]
# **Задание №3**

# %%
# Даны три множества a,b и с. Необходимо выполнить все изученные виды бинарных операций над всеми комбинациями множеств.

A = {0, 5, 7, 8}
B = {1, "a", 5, 9}
C = {0, 1, 5, 7, "c"}

# %%
# Пересечение с помощью оператора "&" или функция intersection()

print(A & B & C)
# Out:
# {5}

# %%
# Разность с помощью оператора "-" или функция difference()
print(A - B - C)
print(A.difference(B).difference(C))
# Out:
# {8}
# {8}

# %%
#Симметричную разность с помощью оператора "^" или функция symmetric_difference()
print(A ^ B ^ C)
print(A.symmetric_difference(B).symmetric_difference(C))
# Out:
# {'c', 5, 'a', 8, 9}
# {'c', 5, 'a', 8, 9}
